# %%
import random
import duckdb
import pandas as pd
random.seed(42)

# %% [markdown]
# ## Création données

# %%
# Table des employés
sales = {
    'order_id': list(range(1110, 1198)),
    'customer_id': random.choices([11, 12, 13, 14, 15, 11, 12, 13, 14], k=88),
}

df_sales = pd.DataFrame(sales)
df_sales["date"] = [d // 3 + 1 for d in range(1, 89)]
df_sales
# Out:
#     order_id  customer_id  date
# 0       1110           11     1
# 1       1111           11     1
# 2       1112           13     2
# 3       1113           13     2
# 4       1114           12     2
# ..       ...          ...   ...
# 83      1193           14    29
# 84      1194           14    29
# 85      1195           12    29
# 86      1196           14    30
# 87      1197           15    30
#
# [88 rows x 3 columns]

# %% [markdown]
# ## Exercice: retrouver tous les clients qui sont venus deux jours de suite

# %% [markdown]
# - Faire un self join pour avoir toutes les combinaisons de commandes possibles pour un même client
# - Retirer les lignes qui correspondent à la combinaison de la même commande
# - Récupérer les lignes où la difference entre la première date et la seconde est = 1

# %% [markdown]
# ### Self join

# %%
combinations_of_sales_per_customer= (
    df_sales.merge(
    df_sales,
    left_on="customer_id",
    right_on="customer_id",
    suffixes=["_first_order", "_second_order"]
    )
)
combinations_of_sales_per_customer
# Out:
#       order_id_first_order  customer_id  date_first_order  \
# 0                     1110           11                 1
# 1                     1110           11                 1
# 2                     1110           11                 1
# 3                     1110           11                 1
# 4                     1110           11                 1
# ...                    ...          ...               ...
# 1753                  1197           15                30
# 1754                  1197           15                30
# 1755                  1197           15                30
# 1756                  1197           15                30
# 1757                  1197           15                30
#
#       order_id_second_order  date_second_order
# 0                      1110                  1
# 1                      1111                  1
# 2                      1117                  3
# 3                      1119                  4
# 4                      1122                  5
# ...                     ...                ...
# 1753                   1125                  6
# 1754                   1142                 12
# 1755                   1145                 13
# 1756                   1187                 27
# 1757                   1197                 30
#
# [1758 rows x 5 columns]

# %% [markdown]
# <img src="images/first_order.gif" />

# %% [markdown]
# ### interlude: s'assurer de la qualité de notre calcul

# %% [markdown]
# On peut s'assurer qu'on a le bon nombre de lignes de la manière suivante:

# %%
(df_sales["customer_id"].value_counts() ** 2).sum()
# Out:
# 1758

# %% [markdown]
# En effet, à chaque fois qu'un client apparaît dans une ligne, il faut joindre cette ligne avec toutes les lignes où il apparaît (y compris la ligne qu'on est en train de traiter)

# %%
df_sales["customer_id"].value_counts()
# Out:
# 11    25
# 13    22
# 14    18
# 12    17
# 15     6
# Name: customer_id, dtype: int64

# %% [markdown]
# (Le client 11 apparaît 25 fois, le client 13 apprarait 22 fois, etc...)

# %% [markdown]
# Pour chaque client, on prends le nombre de fois où il apparaît et on mets ça au carré.
# Si on fait ça pour l'ensemble des clients, ça donne ça:

# %%
df_sales["customer_id"].value_counts() ** 2
# Out:
# 11    625
# 13    484
# 14    324
# 12    289
# 15     36
# Name: customer_id, dtype: int64

# %% [markdown]
# On peut le vérifier en faisant un self-join de la table des ventes du client 15 sur elle-même:

# %%
df_customer_15 = df_sales.query("customer_id == 15")
df_customer_15.merge(
    df_customer_15,
    on="customer_id").shape
# Out:
# (36, 5)

# %% [markdown]
# La somme des carrés de toutes les transactions de chaque client =

# %%
(df_sales["customer_id"].value_counts() ** 2).sum()
# Out:
# 1758

# %% [markdown]
# ### Virer les lignes qui où une commande a été jointe avec elle même :

# %%
mask = (combinations_of_sales_per_customer["order_id_first_order"] != 
        combinations_of_sales_per_customer["order_id_second_order"])
# display(mask)
same_order_removed = combinations_of_sales_per_customer[mask]
same_order_removed
# Out:
#       order_id_first_order  customer_id  date_first_order  \
# 1                     1110           11                 1
# 2                     1110           11                 1
# 3                     1110           11                 1
# 4                     1110           11                 1
# 5                     1110           11                 1
# ...                    ...          ...               ...
# 1752                  1197           15                30
# 1753                  1197           15                30
# 1754                  1197           15                30
# 1755                  1197           15                30
# 1756                  1197           15                30
#
#       order_id_second_order  date_second_order
# 1                      1111                  1
# 2                      1117                  3
# 3                      1119                  4
# 4                      1122                  5
# 5                      1124                  6
# ...                     ...                ...
# 1752                   1121                  5
# 1753                   1125                  6
# 1754                   1142                 12
# 1755                   1145                 13
# 1756                   1187                 27
#
# [1670 rows x 5 columns]

# %%
same_order_removed["delay_between_orders"] = same_order_removed["date_second_order"] - same_order_removed["date_first_order"]
same_order_removed

# beurk, on va voir comment cleaner ça ;)
# Out:
# /tmp/ipykernel_2158/2515210186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   same_order_removed["delay_between_orders"] = same_order_removed["date_second_order"] - same_order_removed["date_first_order"]
#       order_id_first_order  customer_id  date_first_order  \
# 1                     1110           11                 1
# 2                     1110           11                 1
# 3                     1110           11                 1
# 4                     1110           11                 1
# 5                     1110           11                 1
# ...                    ...          ...               ...
# 1752                  1197           15                30
# 1753                  1197           15                30
# 1754                  1197           15                30
# 1755                  1197           15                30
# 1756                  1197           15                30
#
#       order_id_second_order  date_second_order  delay_between_orders
# 1                      1111                  1                     0
# 2                      1117                  3                     2
# 3                      1119                  4                     3
# 4                      1122                  5                     4
# 5                      1124                  6                     5
# ...                     ...                ...                   ...
# 1752                   1121                  5                   -25
# 1753                   1125                  6                   -24
# 1754                   1142                 12                   -18
# 1755                   1145                 13                   -17
# 1756                   1187                 27                    -3
#
# [1670 rows x 6 columns]

# %%
same_order_removed.query("delay_between_orders == 1").shape
# Out:
# (51, 6)

# %% [markdown]
# ## Clean pandas

# %%
combinations_of_sales_per_customer= (
    df_sales.merge(
    df_sales,
    left_on="customer_id",
    right_on="customer_id",
    suffixes=["_first_order", "_second_order"]
    )
)
mask = (combinations_of_sales_per_customer["order_id_first_order"] != 
        combinations_of_sales_per_customer["order_id_second_order"])
same_order_removed = combinations_of_sales_per_customer[mask]
same_order_removed["delay_between_orders"] = same_order_removed["date_second_order"] - same_order_removed["date_first_order"]
same_order_removed.query("delay_between_orders == 1").head(10)
# Out:
# /tmp/ipykernel_1074/2610911840.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   same_order_removed["delay_between_orders"] = same_order_removed["date_second_order"] - same_order_removed["date_first_order"]
#      order_id_first_order  customer_id  date_first_order  \
# 53                   1117           11                 3
# 79                   1119           11                 4
# 105                  1122           11                 5
# 131                  1124           11                 6
# 132                  1124           11                 6
# 210                  1136           11                10
# 235                  1137           11                10
# 287                  1147           11                13
# 313                  1149           11                14
# 339                  1151           11                15
#
#      order_id_second_order  date_second_order  delay_between_orders
# 53                    1119                  4                     1
# 79                    1122                  5                     1
# 105                   1124                  6                     1
# 131                   1127                  7                     1
# 132                   1129                  7                     1
# 210                   1139                 11                     1
# 235                   1139                 11                     1
# 287                   1149                 14                     1
# 313                   1151                 15                     1
# 339                   1154                 16                     1

# %%
(
    df_sales.merge(
        df_sales,
        left_on="customer_id",
        right_on="customer_id",
        suffixes=["_first_order", "_second_order"],
    )
    .query("order_id_first_order != order_id_second_order")
    .query("date_second_order - date_first_order == 1")
)#.head(10)
# Out:
#       order_id_first_order  customer_id  date_first_order  \
# 53                    1117           11                 3
# 79                    1119           11                 4
# 105                   1122           11                 5
# 131                   1124           11                 6
# 132                   1124           11                 6
# 210                   1136           11                10
# 235                   1137           11                10
# 287                   1147           11                13
# 313                   1149           11                14
# 339                   1151           11                15
# 340                   1151           11                15
# 366                   1154           11                16
# 391                   1156           11                16
# 495                   1171           11                21
# 521                   1172           11                22
# 672                   1128           13                 7
# 718                   1138           13                10
# 764                   1146           13                13
# 787                   1148           13                14
# 788                   1148           13                14
# 811                   1152           13                15
# 833                   1153           13                15
# 856                   1155           13                16
# 879                   1157           13                17
# 925                   1174           13                22
# 948                   1176           13                23
# 949                   1176           13                23
# 972                   1178           13                24
# 973                   1178           13                24
# 994                   1179           13                24
# 995                   1179           13                24
# 1064                  1188           13                27
# 1086                  1189           13                27
# 1110                  1114           12                 2
# 1128                  1115           12                 3
# 1146                  1120           12                 4
# 1164                  1123           12                 5
# 1200                  1131           12                 8
# 1344                  1173           12                22
# 1362                  1175           12                23
# 1399                  1116           14                 3
# 1437                  1132           14                 8
# 1438                  1132           14                 8
# 1532                  1159           14                17
# 1551                  1160           14                18
# 1627                  1181           14                25
# 1628                  1181           14                25
# 1685                  1193           14                29
# 1703                  1194           14                29
# 1723                  1121           15                 5
# 1737                  1142           15                12
#
#       order_id_second_order  date_second_order
# 53                     1119                  4
# 79                     1122                  5
# 105                    1124                  6
# 131                    1127                  7
# 132                    1129                  7
# 210                    1139                 11
# 235                    1139                 11
# 287                    1149                 14
# 313                    1151                 15
# 339                    1154                 16
# 340                    1156                 16
# 366                    1158                 17
# 391                    1158                 17
# 495                    1172                 22
# 521                    1177                 23
# 672                    1130                  8
# 718                    1140                 11
# 764                    1148                 14
# 787                    1152                 15
# 788                    1153                 15
# 811                    1155                 16
# 833                    1155                 16
# 856                    1157                 17
# 879                    1162                 18
# 925                    1176                 23
# 948                    1178                 24
# 949                    1179                 24
# 972                    1182                 25
# 973                    1183                 25
# 994                    1182                 25
# 995                    1183                 25
# 1064                   1191                 28
# 1086                   1191                 28
# 1110                   1115                  3
# 1128                   1120                  4
# 1146                   1123                  5
# 1164                   1126                  6
# 1200                   1133                  9
# 1344                   1175                 23
# 1362                   1180                 24
# 1399                   1118                  4
# 1437                   1134                  9
# 1438                   1135                  9
# 1532                   1160                 18
# 1551                   1163                 19
# 1627                   1185                 26
# 1628                   1186                 26
# 1685                   1196                 30
# 1703                   1196                 30
# 1723                   1125                  6
# 1737                   1145                 13

# %% [markdown]
# ## Exercice: faire la même chose en SQL

# %%
# %load solutions/2self_join_orders_following_day.py
# Out:
# ┌─────────────┬─────────────┬──────────────────┬──────────────┬─────────────────┐
# │ customer_id │ first_order │ date_first_order │ second_order │ date_next_order │
# │    int64    │    int64    │      int64       │    int64     │      int64      │
# ├─────────────┼─────────────┼──────────────────┼──────────────┼─────────────────┤
# │          13 │        1188 │               27 │         1191 │              28 │
# │          13 │        1189 │               27 │         1191 │              28 │
# │          14 │        1193 │               29 │         1196 │              30 │
# │          14 │        1194 │               29 │         1196 │              30 │
# │          12 │        1175 │               23 │         1180 │              24 │
# │          15 │        1142 │               12 │         1145 │              13 │
# │          12 │        1173 │               22 │         1175 │              23 │
# │          11 │        1172 │               22 │         1177 │              23 │
# │          13 │        1178 │               24 │         1183 │              25 │
# │          13 │        1179 │               24 │         1183 │              25 │
# │           · │          ·  │                · │           ·  │               · │
# │           · │          ·  │                · │           ·  │               · │
# │           · │          ·  │                · │           ·  │               · │
# │          13 │        1146 │               13 │         1148 │              14 │
# │          12 │        1114 │                2 │         1115 │               3 │
# │          14 │        1116 │                3 │         1118 │               4 │
# │          13 │        1138 │               10 │         1140 │              11 │
# │          11 │        1124 │                6 │         1129 │               7 │
# │          11 │        1124 │                6 │         1127 │               7 │
# │          13 │        1128 │                7 │         1130 │               8 │
# │          11 │        1122 │                5 │         1124 │               6 │
# │          11 │        1119 │                4 │         1122 │               5 │
# │          11 │        1117 │                3 │         1119 │               4 │
# ├─────────────┴─────────────┴──────────────────┴──────────────┴─────────────────┤
# │ 51 rows (20 shown)                                                  5 columns │
# └───────────────────────────────────────────────────────────────────────────────┘
